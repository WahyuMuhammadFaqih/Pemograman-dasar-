# %% [markdown]
# <a href="https://colab.research.google.com/github/WahyuMuhammadFaqih/Pemograman-dasar-/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
# Biodata Saya


nama = "Wahyu Muhammad Faqih"
umur = 19
jurusan = "RPE"
semester = 3
matakuliah = 'Pemograman Dasar'
status_lulus = False


print (nama)
print (umur)
print (jurusan)
print (semester)
print (matakuliah)
print (status_lulus)
# Out:
# Wahyu Muhammad Faqih
# 19
# RPE
# 3
# Pemograman Dasar
# False
